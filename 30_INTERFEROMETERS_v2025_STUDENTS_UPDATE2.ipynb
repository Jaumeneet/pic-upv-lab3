# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 3. Interferometers I - MZI

# %% [markdown]
# Today we will work on the design and modeling of an **Mach-Zenhder Interferometer (MZI)** used in integrated photonic circuits. We will perform simulations that will allow us to understand how it operates.

# %% [markdown]
# ## 0.1 General libraries

# %%
import gdsfactory as gf
import jax
import jax.example_libraries.optimizers as opt
import jax.numpy as jnp
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm

import numpy as np
import sax
from gdsfactory.generic_tech import get_generic_pdk
from scipy import constants
from scipy.constants import c
from scipy.interpolate import interp1d

import gplugins.sax as gs
from gplugins.common.config import PATH

# %% [markdown]
# ## 1. MZI modeling
# Let's compute the transfer function of a MZI

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

wvl = SOI[:, 0]
neffu = SOI[:, 3] #balanced configuration // (neff TE mode)
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ##
# SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
# SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

# wvl0 = SiN_clad[:, 0]
# neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
# neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
Lu = 25; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b)))

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))

H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function delay imbalance')
plt.legend()
plt.grid(True)

plt.show()

# %%
print(SiN_clad[:, 0])
# Out:
# [1.5  1.51 1.52 1.53 1.54 1.55 1.56 1.57 1.58 1.59 1.6 ]

# %% [markdown]
# **Assesment 1.** Please, provide one example of each one of the configurations studied during MZI lecture:
# 1. Balenced configuration
# 2. Unbalanced configuration
#   1.   Phase difference
#   2.   Delay imbalance

# %% [markdown]
# Balanced configuration

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

wvl = SOI[:, 0]
neffu = SOI[:, 3] #balanced configuration // (neff TE mode)
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ##
# SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
# SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

# wvl0 = SiN_clad[:, 0]
# neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
# neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
Lu = 5; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b)))

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))

H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function balanced configuration')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Delay imbalance

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

wvl = SOI[:, 0]
neffu = SOI[:, 3] #balanced configuration // (neff TE mode)
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ##
# SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
# SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

# wvl0 = SiN_clad[:, 0]
# neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
# neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
Lu = 25; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b)))

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))

H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function delay imbalance')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Phase difference

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
#SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

#wvl = SOI[:, 0]
#neffu = SOI[:, 3] #balanced configuration // (neff TE mode)
#neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ##
SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Air.txt', skiprows=1, delimiter='\t')

wvl0 = SiN_clad[:, 0]
neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
Lu = 15; # um
Ld = 15; # um

betau = (2*jnp.pi/wvl0)*neffu0-1j*alphau_np
betad = (2*jnp.pi/wvl0)*neffd0-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
K_a = np.full(wvl0.shape, 0.5)
K_b = np.full(wvl0.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b)))

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))

H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl0, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl0, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function phase difference')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Delay imbalance with $\alpha > 0$

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

wvl = SOI[:, 0]
neffu = SOI[:, 3] #balanced configuration // (neff TE mode)
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ##
# SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
# SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

# wvl0 = SiN_clad[:, 0]
# neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
# neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0.1 #losless case [dB/um]
alphad = 0.1; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
Lu = 25; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b)))

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))

H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function delay imbalance')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Delay imbalance with $γ > 0$

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

wvl = SOI[:, 0]
neffu = SOI[:, 3] #balanced configuration // (neff TE mode)
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ##
# SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
# SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

# wvl0 = SiN_clad[:, 0]
# neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
# neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
Lu = 25; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
gamma_a = 0.2; #null excess loss
gamma_b = 0.2; #null excess loss

# Coupling constant
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b)))

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))

H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function delay imbalance')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Delay imbalance with $γ > 0$ an $ \alpha > 0 $

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

wvl = SOI[:, 0]
neffu = SOI[:, 3] #balanced configuration // (neff TE mode)
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ##
# SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
# SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

# wvl0 = SiN_clad[:, 0]
# neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
# neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0.1 #losless case [dB/um]
alphad = 0.1; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
Lu = 25; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
gamma_a = 0.2; #null excess loss
gamma_b = 0.2; #null excess loss

# Coupling constant
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b)))

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))

H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function delay imbalance')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **Assesment 2.** Taking into account the n_{eff} values for the SOI cross-section, what would be the path difference ($\Delta L$ = $L_u$ - $L_d$) needed to obtain a Free Spectral Range of 40 nm? Introduce the obtained value in the model to check the MZI response. Hint: We assume 1550 nm as the central design wavelength ($\lambda _0$=1550 nm).

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

wvl = SOI[:, 0]
neffu = SOI[:, 3] #balanced configuration // (neff TE mode)
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ##
# SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
# SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

# wvl0 = SiN_clad[:, 0]
# neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
# neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

dneff_dlambda = np.gradient(neffu, wvl)

ng = neffu - wvl * dneff_dlambda

FSR = 0.04  # um

lambda0 = 1.55  # um
idx0 = np.argmin(np.abs(wvl - lambda0))
ng0 = ng[idx0]
DeltaL = lambda0**2 / (ng0 * FSR)

# Path length
Lu = Ld + DeltaL; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b)))

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))

H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function delay imbalance')
plt.legend()
plt.grid(True)

plt.show()

# Derivative of neff
dneff_dlambda = np.gradient(neffu, wvl)

# Group index
ng = neffu - wvl * dneff_dlambda

lambda0 = 1.55  # um
idx0 = np.argmin(np.abs(wvl - lambda0))
ng0 = ng[idx0]

print("Group index at 1550 nm:", ng0)

FSR = 0.04  # um

DeltaL = lambda0**2 / (ng0 * FSR)

print("Required Delta L (um):", DeltaL)
# Out:
# Group index at 1550 nm: 4.29327
# Required Delta L (um): 13.989919105949546

# %% [markdown]
# ## 2. MZI simulation implemented with SAX
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.1 Components S matrix

# %%
# Waveguide Model

def waveguide(wl=1.55, neff=1.6072, length=10.0, loss=0.0) -> sax.SDict:
    phase = 2 * jnp.pi * neff * length / wl
    transmission = 10 ** (-loss * length / 20) * jnp.exp(1j * phase) # loss(dB/um)
    wg_dict = sax.reciprocal(
        {
            ("in0", "out0"): transmission,
        }
    )
    return wg_dict


# Coupler Model

def coupler(coupling=0.5) -> sax.SDict:
    kappa = coupling**0.5
    tau = (1 - coupling) ** 0.5
    coupler_dict = sax.reciprocal(
        {
            ("in0", "out0"): tau,
            ("in0", "out1"): kappa * np.exp(-1j * np.pi / 2.0),
            ("in1", "out0"): kappa * np.exp(-1j * np.pi / 2.0),
            ("in1", "out1"): tau,
        }
    )
    return coupler_dict

# %% [markdown]
# ### 2.2 MZI SAX Circuit Model

# %%
# MZI

mzi, info = sax.circuit(
    netlist={
        "instances": {
            "coup_a": "coupler",
            "wvg_u": "waveguide",
            "wvg_d": "waveguide",
            "coup_b": "coupler",
        },
        "connections": {
            "coup_a,out0": "wvg_d,in0",
            "wvg_d,out0": "coup_b,in0",
            "coup_a,out1": "wvg_u,in0",
            "wvg_u,out0": "coup_b,in1",
        },
        "ports": {
            "in0": "coup_a,in0",
            "in1": "coup_a,in1",
            "out0": "coup_b,out0",
            "out1": "coup_b,out1",
        },
    },
    models={
        "coupler": coupler,
        "waveguide": waveguide,
    },
)

# %% [markdown]
# ### 2.3. MZI Modeling
# **Assesment 3**: Now, we are going to implement the design parameters in the MZI model developed in SAX and compare the response obtained with that simulated by mathematical formulation.
#
# This will help us to identify any error in the definition of the SAX model single components.
#
# In order to implement the SAX model, take as example the following lines:
#
#     mzi_test = mzi(wl=wl,
#                 coup_a = ...
#                 wvg_d={"length": l_d, "neff": ...},
#                 wvg_u={"length": l_u, "neff": ...},
#                 coup_b = ... )
#
#     H00 = mzi_test["in0", "out0"]

# %%
Ld=5
Lu=Ld+DeltaL

mzi_test = mzi(
    wl=wvl,
    coup_a={"coupling": 0.5},
    coup_b={"coupling": 0.5},
    wvg_d={"length": Ld, "neff": neffd},
    wvg_u={"length": Lu, "neff": neffu},
)

H00 = mzi_test["in0", "out0"]
H01 = mzi_test["in0", "out1"]

plt.grid()
plt.plot(wvl, np.abs(H00)**2, label='H00')
plt.plot(wvl, np.abs(H01)**2, label='H01')
plt.legend()
plt.show()

# %% [markdown]
# **Assessment 4.** Designing an MZI for filtering at a specific wavelength. Calculate and adjust the arm lengths to configure the MZI to have a maximum transmission at 1550 nm.
#
# **Assessment 5.** Let's see how the response of the MZI variates with the effective index. Vary the effective index of one of the arms and analyze how the spectrum shifts. To do this, you can use the data provided in the .txt files entitled ‘SiN’.
# Can you give an example of an application where this configuration is used?
#
# **Assessment 6.** Explore how cascading two MZIs affects the transmission spectrum. To do so, design a system in which two MZIs are cascaded. Simulate and observe the spectrum, explaining how the transmission peaks behave.

# %%
mzi_test = mzi(wl=wvl,
            coup_a={"coupling":K_a},
            wvg_u={"wl":wvl, "neff":neffu, "length": Lu, "loss":alphau},
            wvg_d={"wl":wvl, "neff":neffd, "length": Ld, "loss":alphad},
            coup_b={"coupling":K_b},
            )

h00 = mzi_test["in0", "out0"]
h01 = mzi_test["in0", "out1"]
h11 = mzi_test["in1", "out1"]
h10 = mzi_test["in1", "out0"]

H00_dB= 20.0*jnp.log10(np.abs(h00)**2 + 1e-12)  # Adding small value to avoid log(0)
H01_dB= 20.0*jnp.log10(np.abs(h01)**2 + 1e-12)
H10_dB= 20.0*jnp.log10(np.abs(h10)**2 + 1e-12)
H11_dB= 20.0*jnp.log10(np.abs(h11)**2 + 1e-12)

# Plot
plt.figure()
plt.plot(wvl, np.abs(h11)**2, linestyle="-", color=color[8], label=f"h11")
plt.plot(wvl, np.abs(h10)**2, linestyle="--", color=color[8], label=f"h10")
plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.grid(True)
plt.show()

# %% [markdown]
# **Assessment 4.** Designing an MZI for filtering at a specific wavelength. Calculate and adjust the arm lengths to configure the MZI to have a maximum transmission at 1550 nm.

# %%
idx = np.argmin(np.abs(wvl - 1.55))

neff_u_1550 = neffu[idx]
neff_d_1550 = neffd[idx] #vemos que neffu y neffd son iguales en este caso

m = 25
DifL=1.55*m/neff_u_1550
print("Diferencia de longitud (um):", DifL)
# Out:
# Diferencia de longitud (um): 16.44897422074311

# %%
Ld = 5; # um
Lu = Ld + DifL

mzi_test = mzi(
    wl=wvl,
    coup_a={"coupling": 0.5},
    coup_b={"coupling": 0.5},
    wvg_d={"length": Ld, "neff": neffd},
    wvg_u={"length": Lu, "neff": neffu},
)

H00 = mzi_test["in0", "out0"]
H01 = mzi_test["in0", "out1"]

plt.grid()
plt.plot(wvl, np.abs(H00)**2, label='H00')
plt.plot(wvl, np.abs(H01)**2, label='H01')
plt.legend()
plt.show()

# %%
P00 = np.abs(H00)**2
P01 = np.abs(H01)**2

P00_dB = 10*np.log10(P00)
P01_dB = 10*np.log10(P01)

plt.figure()
plt.grid()
plt.plot(wvl, P00_dB, label='H00 (dB)')
plt.plot(wvl, P01_dB, label='H01 (dB)')
plt.legend()
plt.xlabel("Wavelength (um)")
plt.ylabel("Power (dB)")
plt.show()

# %% [markdown]
# **Assessment 5.** Let's see how the response of the MZI variates with the effective index. Vary the effective index of one of the arms and analyze how the spectrum shifts. To do this, you can use the data provided in the .txt files entitled ‘SiN’.
# Can you give an example of an application where this configuration is used?

# %%
# Load SOI and SiN data and interpolate SiN neff onto the SOI wavelength grid
## SiN cross-section ##
SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

wvl0 = SiN_clad[:, 0]
neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
neffu = interp_neffu(wvl)
neffd = interp_neffd(wvl)

Lu = 25.0
Ld = 25.0

dneff_values = [0.1, 0.5, 1, 1.5]

plt.figure()
for dneff in dneff_values:
    neff_u = neff_sin_on_soi + dneff
    mzi_test = mzi(
        wl=wvl_soi,
        coup_a={"coupling": 0.5},
        coup_b={"coupling": 0.5},
        wvg_d={"length": Ld, "neff": neff_sin_on_soi},
        wvg_u={"length": Lu, "neff": neff_u},
    )
    H00 = mzi_test["in0", "out0"]
    plt.plot(wvl_soi, np.abs(H00)**2, label=f"dneff={dneff:.3f}")

plt.xlabel("Wavelength (µm)")
plt.ylabel("|H00|^2")
plt.title("MZI spectrum shift vs. effective index difference (SiN interpolated to SOI wavelengths)")
plt.grid(True)
plt.legend()
plt.show()

print("Example application: tunable optical filters or phase-shift based sensors (thermo‑optic tuning, refractive-index sensing).")
# Out:
# Example application: tunable optical filters or phase-shift based sensors (thermo‑optic tuning, refractive-index sensing).

# %%
## SiN cross-section ##
SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')

wvl0 = SiN_clad[:, 0]
neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
neffd0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)

interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
neffu = interp_neffu(wvl)
neffd = interp_neffd(wvl)

# Propagation loss
alphau = 0
alphad = 0

### Couplers configuration ###
gamma_a = 0
gamma_b = 0

# Path length
idx = np.argmin(np.abs(wvl - 1.55))
neff_1550 = neffu[idx]  # Índice efectivo correspondiente a 1550 nm, que es el centro del rango espectral de interés
m = 50 # Número de períodos para obtener una diferencia de fase de mπ, lo que permite observar varias franjas de interferencia en el espectro
delta_L = 1.55 * m / (2 * neff_1550)
Lu = 5; # um
Ld = Lu - delta_L; # um

# Coupling constant
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# Create multiple simulations with different neff values for upper arm
# Vary the upper arm neff by adding a small perturbation
neff_variations = [0.0, 0.01, 0.02, 0.05]


for delta_neff in neff_variations:
    neffu_test = neffu + delta_neff
   
    mzi_test = mzi(wl=wvl,
        coup_a={"coupling": K_a},
        wvg_d={"length": Ld, "neff": neffd, "loss": alphad},
        wvg_u={"length": Lu, "neff": neffu_test, "loss": alphau},
        coup_b={"coupling": K_b})
   
    H10 = mzi_test["in0", "out1"]
    plt.plot(wvl, np.abs(H10)**2, label=f'Δn_eff = {delta_neff}', linewidth=2)

plt.xlabel('Wavelength (μm)')
plt.ylabel('Transmission')
plt.title('MZI Response vs Effective index variation\n ')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Assessment 6.** Explore how cascading two MZIs affects the transmission spectrum. To do so, design a system in which two MZIs are cascaded. Simulate and observe the spectrum, explaining how the transmission peaks behave.

# %%
import sax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt

# Asumimos que wvl, neffu, neffd ya están cargados y son arrays de JAX
# wvl = jnp.asarray(wvl), etc.
# 1. Construimos el circuito (nombrado correctamente) y mapeamos TODOS los puertos
mzi_cascade_model, info = sax.circuit(
    netlist={
        "instances": {
            "mzi1": "mzi",
            "mzi2": "mzi",
        },
        "connections": {
            "mzi1,out0": "mzi2,in0",  # La conexión principal en cascada
        },
        "ports": {
            "in0": "mzi1,in0",
            "out0": "mzi2,out0",
            "out1": "mzi2,out1",
            # Declaramos los puertos huérfanos para evitar errores de SAX:
            "mzi1_in1": "mzi1,in1",   
            "mzi1_out1": "mzi1,out1", 
            "mzi2_in1": "mzi2,in1",   
        },
    },
    models={"mzi": mzi},
)

# 2. Definimos las longitudes de los brazos (diferente desbalance para cada etapa)
Ld1 = 5.0
Lu1 = 25.0

Ld2 = 5.0
Lu2 = 15.0

# 3. Evaluamos el modelo en cascada
mzi_cascade = mzi_cascade_model(
    wl=wvl,
    mzi1={
        "coup_a": {"coupling": 0.5},
        "coup_b": {"coupling": 0.5},
        "wvg_u": {"length": Lu1, "neff": neffu},
        "wvg_d": {"length": Ld1, "neff": neffd},
    },
    mzi2={
        "coup_a": {"coupling": 0.5},
        "coup_b": {"coupling": 0.5},
        "wvg_u": {"length": Lu2, "neff": neffu},
        "wvg_d": {"length": Ld2, "neff": neffd},
    },
)

# Extraemos las respuestas
H00_cascade = mzi_cascade["in0", "out0"]
# H01_cascade = mzi_cascade["in0", "out1"] # Puedes usarlo si quieres ver el Cross

# 4. Evaluamos el MZI simple para comparar
mzi_single = mzi(
    wl=wvl,
    coup_a={"coupling": 0.5},
    coup_b={"coupling": 0.5},
    wvg_u={"length": Lu1, "neff": neffu},
    wvg_d={"length": Ld1, "neff": neffd},
)
H00_single = mzi_single["in0", "out0"]

# 5. Gráficas (Asegurando np.asarray para Matplotlib)
plt.figure(figsize=(8, 4))
plt.plot(wvl, np.asarray(jnp.abs(H00_single)**2), label="Single MZI (out0)", alpha=0.6)
plt.plot(wvl, np.asarray(jnp.abs(H00_cascade)**2), label="Cascaded MZIs (out0)", linewidth=2)
plt.xlabel("Wavelength (µm)")
plt.ylabel("Transmission |H|^2")
plt.title("Cascaded MZI Transmission (out0) vs Single MZI")
plt.grid(True)
plt.legend()
plt.show()

# %%
mzi2, info = sax.circuit(
    netlist={
        "instances": {
            "mzi1": "mzi",
            "mzi2": "mzi",
        },
        "connections": {
            "mzi1,out0": "mzi2,in0",  # salida del primer MZI a la entrada del segundo
            "mzi1,out1": "mzi2,in1"# mzi1,out1 no se conecta, no hay excitación en in1
        },
        "ports": {
            "in0": "mzi1,in0",        # entrada principal
            "in1": "mzi1,in1",        # entrada complementaria (no excitada)
            "out0": "mzi2,out0",      # salida principal
            "out1": "mzi2,out1",      # salida complementaria

        },
    },
    models={
        "mzi": mzi,
    },
)

# %%
data=np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #cambio el material a SOI porque SiN tiene unicamente 11 puntos y las gráficas no se ven bien, con SOI se tienen más puntos y se pueden apreciar mejor las oscilaciones del MZI
wvl = data[:, 0]
neffd = data[:, 2] 
neffu = data[:, 3]
Lu = 25; # um
Ld= 5
Lu2= 15
Ld2= 10
mzi_cascade = mzi2(
    wl=wvl,
    mzi1={
        "coup_a":{"coupling":0.5},
        "coup_b":{"coupling":0.5},
        "wvg_u":{"length":Lu,"neff":neffu},
        "wvg_d":{"length":Ld,"neff":neffd},
    },
    mzi2={
        "coup_a":{"coupling":0.5},
        "coup_b":{"coupling":0.5},
        "wvg_u":{"length":Lu2,"neff":neffu},
        "wvg_d":{"length":Ld2,"neff":neffd},
    }
)
print(len(wvl))
# Out:
# 41

# %%
H00 = mzi_cascade["in0","out0"]   # salida 0
H01 = mzi_cascade["in0","out1"]   # salida 1

plt.figure(figsize=(8,4))
plt.plot(wvl, np.abs(H00)**2, label="Salida out0")
plt.plot(wvl, np.abs(H01)**2, label="Salida out1")
plt.xlabel("Wavelength (µm)")
plt.ylabel("Transmisión")
plt.grid()
plt.legend()
plt.show()

# %%
import sax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt

# 1. Nombramos el circuito de forma clara
mzi_cascade_model, info = sax.circuit(
    netlist={
        "instances": {
            "mzi1": "mzi",
            "mzi2": "mzi",
        },
        "connections": {
            "mzi1,out0": "mzi2,in0",  
            "mzi1,out1": "mzi2,in1"
        },
        "ports": {
            "in0": "mzi1,in0",        
            "in1": "mzi1,in1",        
            "out0": "mzi2,out0",      
            "out1": "mzi2,out1",      
        },
    },
    models={
        "mzi": mzi, # Asumimos que tienes tu función base 'mzi' definida previamente
    },
)

# 2. Carga de datos
data = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')
wvl = data[:, 0] 
# IMPORTANTE: Si 'wvl' está en nm, descomenta la siguiente línea para pasarlo a um:
# wvl = wvl / 1000.0

neffd = data[:, 2] 
neffu = data[:, 3]

# Convertimos a arrays de JAX para que SAX no se queje
wvl = jnp.asarray(wvl)
neffd = jnp.asarray(neffd)
neffu = jnp.asarray(neffu)

Lu, Ld = 25.0, 5.0   # um
Lu2, Ld2 = 15.0, 10.0 # um

# 3. Evaluación paramétrica (con la variable bien nombrada)
S_cascade = mzi_cascade_model(
    wl=wvl,
    mzi1={
        "coup_a": {"coupling": 0.5},
        "coup_b": {"coupling": 0.5},
        "wvg_u": {"length": Lu, "neff": neffu},
        "wvg_d": {"length": Ld, "neff": neffd},
    },
    mzi2={
        "coup_a": {"coupling": 0.5},
        "coup_b": {"coupling": 0.5},
        "wvg_u": {"length": Lu2, "neff": neffu},
        "wvg_d": {"length": Ld2, "neff": neffd},
    }
)

H00 = S_cascade["in0", "out0"]
H01 = S_cascade["in0", "out1"]

# 4. Gráficas
plt.figure(figsize=(8,4))
# Usamos np.asarray() al graficar porque Matplotlib maneja mejor los arrays clásicos de Numpy
plt.plot(wvl, np.asarray(jnp.abs(H00)**2), label="Salida out0 (Bar)")
plt.plot(wvl, np.asarray(jnp.abs(H01)**2), label="Salida out1 (Cross)")
plt.xlabel("Wavelength (µm)")
plt.ylabel("Transmisión")
plt.grid()
plt.legend()
plt.show()
